# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/112.6 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# %%writefile /content/drive/MyDrive/split_dataset/traffic_signs.yaml
# path: /content/drive/MyDrive/split_dataset
# train: /content/drive/MyDrive/split_dataset/train/images
# val: /content/drive/MyDrive/split_dataset/val/images
# test: /content/drive/MyDrive/split_dataset/test/images
#
# nc: 8
# names:
#   0: No Parking
#   1: Go Ahead
#   2: Turn Left
#   3: Turn Right
#   4: U turn
#   5: Give Way
#   6: Speed Limit 40
#   7: Speed Limit 60
# Out:
# Overwriting /content/drive/MyDrive/split_dataset/traffic_signs.yaml

# %%
# Train YOLO26n on COCO8 for 70 epochs
# !yolo train model=yolo26n.pt data="/content/drive/MyDrive/split_dataset/split_dataset/traffic_signs.yaml" epochs=70 imgsz=640
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # 1. Predict
#
# YOLO26 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO26 Predict Docs](https://docs.ultralytics.com/modes/predict/).

# %%
# Run inference on an image with YOLO26n
# !yolo predict model=/content/drive/MyDrive/trained/best.pt source='/content/drive/MyDrive/split_dataset/test/images/IMG_2496.jpg'
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO26n summary (fused): 122 layers, 2,376,396 parameters, 0 gradients, 5.2 GFLOPs
#
# image 1/1 /content/drive/MyDrive/split_dataset/test/images/IMG_2496.jpg: 640x480 1 No Parking, 69.3ms
# Speed: 4.5ms preprocess, 69.3ms inference, 19.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://docs.ultralytics.com/datasets/detect/coco/) dataset's `val` or `test` splits. The latest YOLO26 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used. See [YOLO26 Val Docs](https://docs.ultralytics.com/modes/val/) for more information.

# %%
# Validate YOLO26n on COCO8 val
# !yolo val model=/content/drive/MyDrive/trained/best.pt data="/content/drive/MyDrive/split_dataset/traffic_signs.yaml"
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO26n summary (fused): 122 layers, 2,376,396 parameters, 0 gradients, 5.2 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.6±0.5 ms, read: 0.0±0.0 MB/s, size: 39.2 KB)
# val: Scanning /content/drive/MyDrive/split_dataset/val/labels... 83 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 83/83 1.6s/it 2:16
# val: New cache created: /content/drive/MyDrive/split_dataset/val/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.8it/s 3.3s
#                    all         83         88      0.656      0.822      0.823      0.462
#             No Parking          4          5      0.336        0.6      0.516      0.256
#               Go Ahead          9          9      0.577      0.889      0.855      0.483
#              Turn Left          4          4      0.639       0.75      0.749       0.58
# ...
